# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from matplotlib.cm import get_cmap

def plot_tsne(user_representations, tsne_perplexity=60, tsne_learning_rate=500, sample_size=1000):
    """
    Plots t-SNE for user representations with different colors for each interest and displays the plot.

    Args:
        user_representations (np.ndarray): User representations (users x interests x features).
        tsne_perplexity (int): Perplexity parameter for t-SNE.
        tsne_learning_rate (int): Learning rate parameter for t-SNE.
        sample_size (int): Number of samples to use for t-SNE. Default is 1000.
    """
    if not isinstance(user_representations, np.ndarray):
        user_representations = np.array(user_representations)
    
    if user_representations.shape[0] > sample_size:
        indices = np.random.choice(user_representations.shape[0], sample_size, replace=False)
        user_representations_sample = user_representations[indices]
    else:
        user_representations_sample = user_representations
    
    # Flatten the user representations for t-SNE
    num_interests = user_representations_sample.shape[1]
    user_representations_flat = user_representations_sample.reshape(-1, user_representations_sample.shape[-1])

    # t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=tsne_perplexity, learning_rate=tsne_learning_rate, n_jobs=-1)
    user_representations_tsne = tsne.fit_transform(user_representations_flat)

    # Plot t-SNE with different colors for each interest
    cmap = get_cmap('tab10')  # Colormap for distinct colors
    plt.figure(figsize=(10, 5))

    # Loop over each user group of interests and assign distinct colors
    for interest_idx in range(num_interests):
        indices = np.arange(interest_idx, user_representations_tsne.shape[0], num_interests)
        plt.scatter(user_representations_tsne[indices, 0], user_representations_tsne[indices, 1], 
                    alpha=0.6, color=cmap(interest_idx % cmap.N))  # Assign colors cyclically

    plt.title(f't-SNE of User Representations (perplexity={tsne_perplexity}, lr={tsne_learning_rate})')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    plt.show()  # Display the plot
    plt.close()

# %%
#N=5 without disentanglement

# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N5_user_representations/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=5 with disentanglement

# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N5_dis_cos_bce_lamda_s_0.9/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=10 without disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N10_user_representations/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=10 with disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N10_dis_cos_bce_lamda_s_0.9_user_representations/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=25 without disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N25_user_representations/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=25 with disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N25_dis_cos_bce_lamda_s_0.9/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=50 without disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N50_user_representations/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors

# %%
#N=50 with disentanglement
# Load user representations from pickle file
pickle_file_path = '/mount/arbeitsdaten/tcl/tclext/godbolai/codethesis/nrs/experiments/MI_N50_dis_cos_bce_lamda_s_0.90/user_representations.pkl'
with open(pickle_file_path, 'rb') as f:
    user_representations = pickle.load(f)

plot_tsne(user_representations)
# Out:
# /tmp/ipykernel_3689383/4188033629.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab10')  # Colormap for distinct colors
